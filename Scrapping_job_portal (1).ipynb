# %% [markdown]
# <div class="markdown-google-sans">
#   <h1>Welcome to Colab!</h1>
# </div>
#
# If you're already familiar with Colab, check out this video to learn about interactive tables, the executed code history view, and the command palette.
#
# <center>
#   <a href="https://www.youtube.com/watch?v=rNgswRZ2C1Y" target="_blank">
#   <img alt='Thumbnail for a video showing 3 cool Google Colab features' src="data:image/png;base64,..." height="188" width="336">
#   </a>
# </center>

# %% [markdown]
# <div class="markdown-google-sans">
#   <h2>What is Colab?</h2>
# </div>
#
# Colab, or "Colaboratory", allows you to write and execute Python in your browser, with
# - Zero configuration required
# - Access to GPUs free of charge
# - Easy sharing
#
# Whether you're a **student**, a **data scientist** or an **AI researcher**, Colab can make your work easier. Watch [Introduction to Colab](https://www.youtube.com/watch?v=inN8seMm7UI) to learn more, or just get started below!

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## **Getting started**
# </div>
#
# The document you are reading is not a static web page, but an interactive environment called a **Colab notebook** that lets you write and execute code.
#
# For example, here is a **code cell** with a short Python script that computes a value, stores it in a variable, and prints the result:

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400

# %% [markdown]
# To execute the code in the above cell, select it with a click and then either press the play button to the left of the code, or use the keyboard shortcut "Command/Ctrl+Enter". To edit the code, just click the cell and start editing.
#
# Variables that you define in one cell can later be used in other cells:

# %%
seconds_in_a_week = 7 * seconds_in_a_day
seconds_in_a_week
# Out:
# 604800

# %% [markdown]
# Colab notebooks allow you to combine **executable code** and **rich text** in a single document, along with **images**, **HTML**, **LaTeX** and more. When you create your own Colab notebooks, they are stored in your Google Drive account. You can easily share your Colab notebooks with co-workers or friends, allowing them to comment on your notebooks or even edit them. To learn more, see [Overview of Colab](/notebooks/basic_features_overview.ipynb). To create a new Colab notebook you can use the File menu above, or use the following link: [create a new Colab notebook](http://colab.research.google.com#create=true).
#
# Colab notebooks are Jupyter notebooks that are hosted by Colab. To learn more about the Jupyter project, see [jupyter.org](https://www.jupyter.org).

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Data science
# </div>
#
# With Colab you can harness the full power of popular Python libraries to analyze and visualize data. The code cell below uses **numpy** to generate some random data, and uses **matplotlib** to visualize it. To edit the code, just click the cell and start editing.

# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)

plt.title("Sample Visualization")
plt.show()

# %% [markdown]
# You can import your own data into Colab notebooks from your Google Drive account, including from spreadsheets, as well as from Github and many other sources. To learn more about importing data, and how Colab can be used for data science, see the links below under [Working with Data](#working-with-data).

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Machine learning
# </div>
#
# With Colab you can import an image dataset, train an image classifier on it, and evaluate the model, all in just [a few lines of code](https://colab.research.google.com/github/tensorflow/docs/blob/master/site/en/tutorials/quickstart/beginner.ipynb). Colab notebooks execute code on Google's cloud servers, meaning you can leverage the power of Google hardware, including [GPUs and TPUs](#using-accelerated-hardware), regardless of the power of your machine. All you need is a browser.

# %% [markdown]
# Colab is used extensively in the machine learning community with applications including:
# - Getting started with TensorFlow
# - Developing and training neural networks
# - Experimenting with TPUs
# - Disseminating AI research
# - Creating tutorials
#
# To see sample Colab notebooks that demonstrate machine learning applications, see the [machine learning examples](#machine-learning-examples) below.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## More Resources
#
# ### Working with Notebooks in Colab
#
# </div>
#
# - [Overview of Colaboratory](/notebooks/basic_features_overview.ipynb)
# - [Guide to Markdown](/notebooks/markdown_guide.ipynb)
# - [Importing libraries and installing dependencies](/notebooks/snippets/importing_libraries.ipynb)
# - [Saving and loading notebooks in GitHub](https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/colab-github-demo.ipynb)
# - [Interactive forms](/notebooks/forms.ipynb)
# - [Interactive widgets](/notebooks/widgets.ipynb)
# - <img src="/img/new.png" height="20px" align="left" hspace="4px" alt="New"></img>
#
# <div class="markdown-google-sans">
#
# <a name="working-with-data"></a>
# ### Working with Data
# </div>
#
# - [Loading data: Drive, Sheets, and Google Cloud Storage](/notebooks/io.ipynb)
# - [Charts: visualizing data](/notebooks/charts.ipynb)
# - [Getting started with BigQuery](/notebooks/bigquery.ipynb)
#
# <div class="markdown-google-sans">
#
# ### Machine Learning Crash Course
#
# <div>
#
# These are a few of the notebooks from Google's online Machine Learning course. See the [full course website](https://developers.google.com/machine-learning/crash-course/) for more.
# - [Intro to Pandas DataFrame](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/pandas_dataframe_ultraquick_tutorial.ipynb)
# - [Linear regression with tf.keras using synthetic data](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/linear_regression_with_synthetic_data.ipynb)
#
# <div class="markdown-google-sans">
#
# <a name="using-accelerated-hardware"></a>
# ### Using Accelerated Hardware
# </div>
#
# - [TensorFlow with GPUs](/notebooks/gpu.ipynb)
# - [TensorFlow with TPUs](/notebooks/tpu.ipynb)

# %% [markdown]
# <div class="markdown-google-sans">
#
# <a name="machine-learning-examples"></a>
#
# ### Featured examples
#
# </div>
#
# - [NeMo Voice Swap](https://colab.research.google.com/github/NVIDIA/NeMo/blob/stable/tutorials/VoiceSwapSample.ipynb): Use Nvidia's NeMo conversational AI Toolkit to swap a voice in an audio fragment with a computer generated one.
#
# - [Retraining an Image Classifier](https://tensorflow.org/hub/tutorials/tf2_image_retraining): Build a Keras model on top of a pre-trained image classifier to distinguish flowers.
# - [Text Classification](https://tensorflow.org/hub/tutorials/tf2_text_classification): Classify IMDB movie reviews as either *positive* or *negative*.
# - [Style Transfer](https://tensorflow.org/hub/tutorials/tf2_arbitrary_image_stylization): Use deep learning to transfer style between images.
# - [Multilingual Universal Sentence Encoder Q&A](https://tensorflow.org/hub/tutorials/retrieval_with_tf_hub_universal_encoder_qa): Use a machine learning model to answer questions from the SQuAD dataset.
# - [Video Interpolation](https://tensorflow.org/hub/tutorials/tweening_conv3d): Predict what happened in a video between the first and the last frame.

# %% [markdown]
# **WEBSCRAPING USING BEAUTIFUL SOUP**

# %% [markdown]
# Web scraping is the process of extracting data from websites using computer programs. It is essential in data science as it enables businesses to gather information from various online sources for analysis and modeling.
#
# There are multiple ways to perform web scraping:
#
# 1. API: APIs provide protocols and tools to access web-based data and services like webpages, images, and other content.
#
# 2. HTML Parsers: These programs parse HTML documents and extract data from them, specifically designed to access and retrieve content from webpages.
#
# 3. Scrapy: Scrapy is a Python-based web scraping framework that offers a comprehensive toolkit for scraping websites. It allows crawling multiple pages, extracting data, and structuring it for storage.
#
# 4. Selenium: Selenium is an open-source tool that automates web browsers. It can simulate user interactions with web pages and extract data accordingly.
#
# 5. Wget/Curl: Wget and Curl are command-line programs that download webpages and web-based resources. They can be utilized to access and scrape web content.
#
# These techniques enable quick and cost-effective data collection from various online sources, facilitating data science projects.

# %%
import warnings
warnings.filterwarnings("ignore")
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rcParams['font.size'] = 12

# %%
url = 'https://www.shine.com/job-search/jobs?job_type=2&top_companies_boost=true&sort=1'
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.text,'html.parser')
html = soup.find_all('div')

# %% [markdown]
# **Fetching JOB Titles**

# %% [markdown]
# code retrieves job titles from the web page using Beautiful Soup's select() method, stores them in the titles list, and then displays the first five titles

# %%
req = soup.select('div h2[itemprop="name"]')
titles = [r.text for r in req]
titles[:5]
# Out:
# ['Field Sales Executive',
#  'Relationship Manager',
#  'Tele Sales Executive, Tele sales representative, custom ...',
#  'Sme Manager',
#  'Tele Sales Executive']

# %% [markdown]
# these modifications in the code remove the "|" characters and extra spaces from the job titles, resulting in cleaner and more standardized titles in the titles list.

# %%
titles1 = [t.replace("|","") for t in titles]
titles = [t.replace("  ", "") for t in titles1]
titles[:5]
# Out:
# ['Field Sales Executive',
#  'Relationship Manager',
#  'Tele Sales Executive, Tele sales representative, custom ...',
#  'Sme Manager',
#  'Tele Sales Executive']

# %% [markdown]
# **Fetching Employer's name**

# %% [markdown]
# this code retrieves employer names from the web page, processes them to remove the substring "Hiring", and stores the modified names in the companies list. The code then prints the first five modified employer names.

# %%
orgs = soup.find_all('div', class_='jobCard_jobCard_cName__mYnow')
orgs1 = [o.text for o in orgs]
[o for o in orgs1][:5]
# Out:
# ['Hinduja Global Solutions Limited (H...',
#  'VNU CONSULTING SERVICES Hiring For ...',
#  'VINTAQE MANAGEMENT SOLUTIONS PRIVAT...',
#  'Kotak Mahindra Life Insurance Compa...',
#  'UTTAM FINANCIAL SERVICES']

# %%
sub_str = "Hiring"
[o.split(sub_str)[0] for o in orgs1][:5]
# Out:
# ['Hinduja Global Solutions Limited (H...',
#  'VNU CONSULTING SERVICES ',
#  'VINTAQE MANAGEMENT SOLUTIONS PRIVAT...',
#  'Kotak Mahindra Life Insurance Compa...',
#  'UTTAM FINANCIAL SERVICES']

# %%
companies = [o.split(sub_str)[0] for o in orgs1]
companies[:5]
# Out:
# ['Hinduja Global Solutions Limited (H...',
#  'VNU CONSULTING SERVICES ',
#  'VINTAQE MANAGEMENT SOLUTIONS PRIVAT...',
#  'Kotak Mahindra Life Insurance Compa...',
#  'UTTAM FINANCIAL SERVICES']

# %% [markdown]
# **Fetching Job Locations**

# %% [markdown]
# this code retrieves job locations from the web page, processes them by replacing characters and removing digits, and stores the modified locations in the location list. The code then prints the modified job locations for the first five items in the list.

# %%
loc = soup.find_all('div', class_='jobCard_jobCard_lists__fdnsc')

# %%
[l.text[10:] for l in loc]
# Out:
# ['Hyderabad',
#  'Nashik+5Dhule, Solapur, Latur, Aurangabad, Nagpur',
#  'elhi',
#  'Thane',
#  'ucknow',
#  'Noida+1Delhi',
#  'Gurugram+1Delhi',
#  'ur+4Bangalore, Kanpur, Lucknow, Pune',
#  'Bangalore',
#  'Udaipur',
#  'Kolkata',
#  'Delhi',
#  'Bangalore+3Hyderabad, Gurugram, Delhi',
#  'rsMumbai City',
#  'Mumbai City',
#  'Bangalore',
#  'Chennai',
#  'Bangalore',
#  'Pune',
#  'Mumbai City']

# %%
loc1 = [l.text[10:] for l in loc]

# %%
[l.replace("+", ",") for l in loc1][:5]
# Out:
# ['Hyderabad',
#  'Nashik,5Dhule, Solapur, Latur, Aurangabad, Nagpur',
#  'elhi',
#  'Thane',
#  'ucknow']

# %%
loc2 = [l.replace("+", ",") for l in loc1]

# %%
pattern  = r'[0-9]'
strpattern = r'[a-z]'

# %%
[re.sub(pattern, '', l) for l in loc2][:5]
# Out:
# ['Hyderabad',
#  'Nashik,Dhule, Solapur, Latur, Aurangabad, Nagpur',
#  'elhi',
#  'Thane',
#  'ucknow']

# %%
location = [re.sub(pattern, '', l) for l in loc2]

# %%
location[:5]
# Out:
# ['Hyderabad',
#  'Nashik,Dhule, Solapur, Latur, Aurangabad, Nagpur',
#  'elhi',
#  'Thane',
#  'ucknow']

# %% [markdown]
# **Fetching Experience**

# %%
[l.text[:10] for l in loc][:5]
# Out:
# ['1 to 5 Yrs', '1 to 2 Yrs', '0 to 1 YrD', '2 to 5 Yrs', '0 to 1 YrL']

# %%
experience = [l.text[:10] for l in loc]

# %%
experience[:5]
# Out:
# ['1 to 5 Yrs', '1 to 2 Yrs', '0 to 1 YrD', '2 to 5 Yrs', '0 to 1 YrL']

# %% [markdown]
# **Fetching number of positions**

# %%
vacancies = soup.find_all('ul', class_='jobCard_jobCard_jobDetail__jD82J')

# %%
[v.text.split("Positions")[0] for v in vacancies ][:10]
# Out:
# ['Be an Early ApplicantContractual95 ',
#  'Be an Early ApplicantRegular20 ',
#  'Be an Early ApplicantRegular18 ',
#  'Be an Early ApplicantRegular8 ',
#  'Regular20 ',
#  'Be an Early ApplicantRegular',
#  'Be an Early ApplicantRegular20 ',
#  'Be an Early ApplicantRemote5 ',
#  'Be an Early ApplicantRegular',
#  'Be an Early ApplicantRegular99 ']

# %%
[v.text.split("Positions")[0][-3:-1] for v in vacancies ][:10]
# Out:
# ['95', '20', '18', 'r8', '20', 'la', '20', 'e5', 'la', '99']

# %%
vac = [v.text.split("Positions")[0][-3:] for v in vacancies ]
vac = [v.replace('la', '1') for v in vac]
vac = [re.sub(strpattern, '', l) for l in vac]

# %%
vacancies= [v.replace(' ','') for v in vac]

# %%
vacancies[:5]
# Out:
# ['95', '20', '18', '8', '20']

# %% [markdown]
# **Converting to Data Frames**

# %%
df = pd.DataFrame({'Titles':titles, 'Firm Name': companies, 'Job Location':location, 'Experience':experience,
                   'Positions': vacancies})

# %%
df.head()
# Out:
#                                               Titles  \
# 0                              Field Sales Executive
# 1                               Relationship Manager
# 2  Tele Sales Executive, Tele sales representativ...
# 3                                        Sme Manager
# 4                               Tele Sales Executive
#
#                                 Firm Name  \
# 0  Hinduja Global Solutions Limited (H...
# 1                VNU CONSULTING SERVICES
# 2  VINTAQE MANAGEMENT SOLUTIONS PRIVAT...
# 3  Kotak Mahindra Life Insurance Compa...
# 4                UTTAM FINANCIAL SERVICES
#
#                                        Job Location  Experience Positions
# 0                                         Hyderabad  1 to 5 Yrs        95
# 1  Nashik,Dhule, Solapur, Latur, Aurangabad, Nagpur  1 to 2 Yrs        20
# 2                                              elhi  0 to 1 YrD        18
# 3                                             Thane  2 to 5 Yrs         8
# 4                                            ucknow  0 to 1 YrL        20

# %%
df['Titles'].duplicated().sum()
# Out:
# 1

# %% [markdown]
# **Removing Duplicates**

# %% [markdown]
# The code you provided is using the drop_duplicates() method on a DataFrame df to remove duplicates based on the 'Titles' column

# %%
df = df.drop_duplicates(subset=['Titles'])

# %%
df.head()
# Out:
#                                               Titles  \
# 0                              Field Sales Executive
# 1                               Relationship Manager
# 2  Tele Sales Executive, Tele sales representativ...
# 3                                        Sme Manager
# 4                               Tele Sales Executive
#
#                                 Firm Name  \
# 0  Hinduja Global Solutions Limited (H...
# 1                VNU CONSULTING SERVICES
# 2  VINTAQE MANAGEMENT SOLUTIONS PRIVAT...
# 3  Kotak Mahindra Life Insurance Compa...
# 4                UTTAM FINANCIAL SERVICES
#
#                                        Job Location  Experience Positions
# 0                                         Hyderabad  1 to 5 Yrs        95
# 1  Nashik,Dhule, Solapur, Latur, Aurangabad, Nagpur  1 to 2 Yrs        20
# 2                                              elhi  0 to 1 YrD        18
# 3                                             Thane  2 to 5 Yrs         8
# 4                                            ucknow  0 to 1 YrL        20

# %%
df['Positions'] = df['Positions'].astype('int32')
#Creating a New Column
numpattern = r'[0]'
df['Category'] = ['Fresher' if '0' in i else 'Experienced' for i in df['Experience']]

# %%
#DataFrame created based on Descending values
df.sort_values(by='Positions', ascending=False)
# Out:
#                                                Titles  \
# 9                          Agency Development Manager
# 17                     Business Development Executive
# 0                               Field Sales Executive
# 15                      Urgent Requirement Spot Offer
# 16                                      Sales Officer
# 4                                Tele Sales Executive
# 6   Urgent I Walkin interview at Aditya Birla capi...
# 1                                Relationship Manager
# 2   Tele Sales Executive, Tele sales representativ...
# 13  Walk-in Drive Bancassurance Manager Banca Mumb...
# 14  Walk-in Drive- Bancassurance Manager-Banca- Mu...
# 3                                         Sme Manager
# 7                      HTML and PHP Website Developer
# 19    RELATIONSHIP MANAGER , SR.RELATIONSHIP MANAGER.
# 10                       Business Development Manager
# 11                            Import Export Executive
# 5   Team Leader (Recruitment Manager), Executive S...
# 8                    Hiring BDE , Sales Officer , ASM
# 12                               Business Development
#
#                                  Firm Name  \
# 9              Times Consultancy Services
# 17  Square Yards Consulting Private Lim...
# 0   Hinduja Global Solutions Limited (H...
# 15           Wroots Global Private Limited
# 16  Hinduja Global Solutions Limited (H...
# 4                 UTTAM FINANCIAL SERVICES
# 6   ADITYA BIRLA SUN LIFE INSURANCE COM...
# 1                 VNU CONSULTING SERVICES
# 2   VINTAQE MANAGEMENT SOLUTIONS PRIVAT...
# 13                     Aspire ERP Systems
# 14                     Aspire ERP Systems
# 3   Kotak Mahindra Life Insurance Compa...
# 7                         Narendra Sharma
# 19              RCJ Employ HR Services LLP
# 10              SWELLWELL MINECHEM PVT LTD
# 11                  Qatar Manpower Agency
# 5   ACUTE VISION CONSULTANTS PRIVATE LI...
# 8   HIGHSOURCE HR SOLUTIONS PRIVATE LIM...
# 12                        ULTIMA CHEMICALS
#
#                                         Job Location  Experience  Positions  \
# 9                                            Udaipur  1 to 6 Yrs         99
# 17                                         Bangalore  0 to 2 Yrs         99
# 0                                          Hyderabad  1 to 5 Yrs         95
# 15                                         Bangalore  0 to 3 Yrs         50
# 16                                           Chennai  0 to 5 Yrs         50
# 4                                             ucknow  0 to 1 YrL         20
# 6                                     Gurugram,Delhi  0 to 4 Yrs         20
# 1   Nashik,Dhule, Solapur, Latur, Aurangabad, Nagpur  1 to 2 Yrs         20
# 2                                               elhi  0 to 1 YrD         18
# 13                                     rsMumbai City  10 to 18 Y         10
# 14                                       Mumbai City  4 to 9 Yrs         10
# 3                                              Thane  2 to 5 Yrs          8
# 7                ur,Bangalore, Kanpur, Lucknow, Pune  0 YrsSitap          5
# 19                                       Mumbai City  0 to 5 Yrs          5
# 10                                           Kolkata  1 to 6 Yrs          3
# 11                                             Delhi  0 to 2 Yrs          2
# 5                                        Noida,Delhi  3 to 8 Yrs          1
# 8                                          Bangalore  0 to 2 Yrs          1
# 12              Bangalore,Hyderabad, Gurugram, Delhi  0 to 4 Yrs          1
#
#        Category
# 9   Experienced
# 17      Fresher
# 0   Experienced
# 15      Fresher
# 16      Fresher
# 4       Fresher
# 6       Fresher
# 1   Experienced
# 2       Fresher
# 13      Fresher
# 14  Experienced
# 3   Experienced
# 7       Fresher
# 19      Fresher
# 10  Experienced
# 11      Fresher
# 5   Experienced
# 8       Fresher
# 12      Fresher

# %% [markdown]
# scraping job data from multiple pages of the job portal and storing it in lists (TITLES, COMPANIES, LOCATIONS, EXPERIENCE, and VACANCIES). It then creates a DataFrame using pandas to organize the scraped data.

# %%
TITLES = []

COMPANIES = []
LOCATIONS = []
EXPERIENCE = []
VACANCIES = []

for i in range(1,6):
    link = f'https://www.shine.com/job-search/jobs-{i}?job_type=2&top_companies_boost=true&sort=1'
    response = requests.get(link)

    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')

        req = soup.select('div h2[itemprop="name"]')
        titles = [r.text for r in req]
        titles1 = [t.replace("|","") for t in titles]
        titles = [t.replace("  ", "") for t in titles1]
        TITLES.extend(titles)

        orgs = soup.find_all('div', class_='jobCard_jobCard_cName__mYnow')
        orgs1 = [o.text for o in orgs]
        sub_str = "Hiring"
        companies = [o.split(sub_str)[0] for o in orgs1]
        COMPANIES.extend(companies)

        loc = soup.find_all('div', class_='jobCard_jobCard_lists__fdnsc')
        loc1 = [l.text[10:] for l in loc]
        loc2 = [l.replace("+", ",") for l in loc1]
        pattern  = r'[0-9]'
        strpattern = r'[a-z]'
        location = [re.sub(pattern, '', l) for l in loc2]
        LOCATIONS.extend(location)

        experience = [l.text[:10] for l in loc]
        EXPERIENCE.extend(experience)

        vacancies = soup.find_all('ul', class_='jobCard_jobCard_jobDetail__jD82J')
        vac = [v.text.split("Positions")[0][-3:] for v in vacancies ]
        vac = [v.replace('la', '1') for v in vac]
        vac = [re.sub(strpattern, '', l) for l in vac]
        vacancies= [v.replace(' ','') for v in vac]
        VACANCIES.extend(vacancies)

    else:
        print('Invalid Response')

df = pd.DataFrame({'Job Title': TITLES,
                   'Employer': COMPANIES,
                   'Job Location': LOCATIONS,
                   'Experience': EXPERIENCE,
                   'Positions': VACANCIES})

# %% [markdown]
# **Visualizing Data**

# %%
df.head()
# Out:
#                                            Job Title  \
# 0                              Field Sales Executive
# 1                               Relationship Manager
# 2  Tele Sales Executive, Tele sales representativ...
# 3                                        Sme Manager
# 4                               Tele Sales Executive
#
#                                  Employer  \
# 0  Hinduja Global Solutions Limited (H...
# 1                VNU CONSULTING SERVICES
# 2  VINTAQE MANAGEMENT SOLUTIONS PRIVAT...
# 3  Kotak Mahindra Life Insurance Compa...
# 4                UTTAM FINANCIAL SERVICES
#
#                                        Job Location  Experience Positions
# 0                                         Hyderabad  1 to 5 Yrs        95
# 1  Nashik,Dhule, Solapur, Latur, Aurangabad, Nagpur  1 to 2 Yrs        20
# 2                                              elhi  0 to 1 YrD        18
# 3                                             Thane  2 to 5 Yrs         8
# 4                                            ucknow  0 to 1 YrL        20

# %%
df = df.drop_duplicates(subset=['Job Title'])

# %%
df.Positions = pd.to_numeric(df.Positions)

# %%
plt.figure(figsize=(22,5), dpi=100)
ax = sns.barplot(x=df['Employer'][:10], y=df['Positions'][:10])
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.title('Firm Wise vacancy count', fontsize=20)
plt.axhline(df.Positions.mean(), color='red')

#Annotating each bar
for bar in ax.patches:
    ax.annotate(format(bar.get_height(), '.0f'),(bar.get_x() + bar.get_width() / 2,bar.get_height()),
                 ha='center', va='center',size=15, xytext=(0, 8),textcoords='offset points')
#coloring each bar based on a condition if the bar value is greator or less than count of positions for a given firm
for i in range(len(ax.patches)):
    #getting the count of each bar
    counts = [p.get_height() for p in ax.patches]
    #getting the colors based on the condition for each bar
    colors = ['#38A7D0' if j > df.Positions.mean() else '#F67088' for j in counts]
    #passing the color for each bar
    ax.patches[i].set_facecolor(colors[i])

plt.xticks(rotation=45)
plt.show()

# %%
palette = ['#38A7D0', '#F67088']
plt.figure(figsize=(22,5), dpi=100)
ax = sns.countplot(data =df,x=df['Experience'][:10], hue=df['Experience'][:10], dodge=False, palette=palette)
for bar in ax.patches:
    ax.annotate(format(bar.get_height(), '.0f'),(bar.get_x() + bar.get_width() / 2,bar.get_height()),
                 ha='center', va='center',size=15, xytext=(0, 8),textcoords='offset points')
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.title('Category Count Plot', fontsize=20)
plt.show()
